# %%
import matplotlib.pyplot as plt

# %%
x=[2,4,6,8,10]
y=[1,2,3,4,5]

# %%
#plot values
plt.plot(x,y)

# %%
x=[2,4,7,9,10]
y=[-1,2-3,4,-5]

# %%
#plot values
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 #plot values
# ----> 2 plt.plot(x,y)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...

# %%
x=[2,4,6,8,10]
y=[1,2,3,4,5]
#plot values
plt.plot(x,y)

# %%
#x lable
plt.xlable("sales")
#y lable
plt.ylable("profit")
#title
plt.title("sales vs profit")
#plot values
plt,plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 #x lable
# ----> 2 plt.xlable("sales")
#       3 #y lable
#       4 plt.ylable("profit")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y)

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,linestyle='dotted')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='r')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='r',linestyle='dotted')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='r',linestyle='dotted',marker='+')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='r',linestyle='dotted',marker='o')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='b',marker='+'ms=25)
# Out:
#   Input In [23]
#     plt.plot(x,y,color='b',marker='+'ms=25)
#                                      ^
# SyntaxError: invalid syntax

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.plot(x,y,color='b',marker='+',ms=25)

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y)

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,ms=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [28], in <cell line: 8>()
#       6 plt.title("sales vs profit")
#       7 #plot values
# ----> 8 plt.scatter(x,y,ms=20)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,marker='+')
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
#x label
plt.xlabel("sales")
#y lable
plt.ylabel("profit")
#title
plt.title("sales vs profit")
#plot values
plt.scatter(x,y,color='b',marker='+')
plt.bar(y,x)
# Out:
# <BarContainer object of 5 artists>

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([40,50,60,70,80,90])
plt.plot(a,b)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)
#plot1
plt.subplot(2,2,3)
plt.plot(a,d)
#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)
#plot2
plt.subplot(2,2,4)
plt.plot(c,d)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)
#plot1
plt.subplot(2,2,1)
plt.plot(a,d)
#plot2
plt.subplot(2,2,2)
plt.plot(c,d)
#plot3
plt.subplot(2,2,3)
plt.plot(b,d)
#plot4
plt.subplot(2,2,4)
plt.plot(d,a)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d)
#plot1
plt.subplot(3,2,1)
plt.plot(a,d)
#plot2
plt.subplot(3,2,2)
plt.plot(c,d)
#plot3
plt.subplot(3,2,3)
plt.plot(b,d)
#plot4
plt.subplot(3,2,4)
plt.plot(d,a)

# %%
#subplot
import numpy as np
a=np.array([44,55,66,77,88,99])
b=np.array([41,52,63,74,85,96])
c=np.array([14,15,16,17,18,19])
d=np.array([10,13,23,31,50,54])
plt.plot(a,d,color='b')
#plot1
plt.subplot(3,2,1)
plt.plot(a,d,color='g')
#plot2
plt.subplot(3,2,5)
plt.plot(c,d,color='y')
#plot3
plt.subplot(3,2,3)
plt.plot(b,d,color='r')
#plot4
plt.subplot(3,2,4)
plt.plot(d,a,color='b')

# %%
#Histogram
data=np.random.normal(150,10,250)

# %%
data
# Out:
# array([129.58206599, 144.31167037, 141.99351829, 157.30187732,
#        124.85371911, 156.82604098, 142.49374619, 162.23179422,
#        149.30023807, 150.25365196, 172.57455246, 140.48260402,
#        144.14898967, 158.63189637, 147.7942381 , 176.85999774,
#        151.10259119, 137.40573744, 160.38102417, 142.57282173,
#        144.02042284, 152.36435277, 148.50318223, 159.54797888,
#        162.96213508, 166.27673119, 145.06279554, 164.54051586,
#        155.97970825, 145.71013439, 145.00676244, 123.42249584,
#        144.24904481, 160.157148  , 156.11229598, 153.24079895,
#        153.39851613, 166.6713415 , 149.69134665, 162.65162528,
#        151.4073957 , 147.06406793, 144.68270368, 166.8839892 ,
#        149.63024978, 138.84212133, 150.63828909, 152.51827469,
#        136.46240049, 164.02091383, 140.72093075, 149.6131383 ,
#        141.19895468, 147.43493872, 163.26882605, 147.32011926,
#        141.35156123, 145.33378153, 144.12060767, 160.78798773,
# ...

# %%
len(data)
# Out:
# 250

# %%
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=np.array([44,55,66,77,88,99])
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data1,bins=20)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 plt.hist(data1,bins=20)
#       2 plt.show
#
# NameError: name 'data1' is not defined

# %%
plt.hist(data,bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=np.random.normal([54,66,78,68,67,89,92,96,75,55,88,82,49,77,46,74,69,99])

# %%
plt.hist(data,bins=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#pie chart

#create dataset
cars=['AUDI','BMW','FORD','BUGHATI']
sale=[70,56,40,120]
#create pie chart
plt.pie(sale)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
